# %% [markdown]
# # Queueing Model

# %% [markdown]
# You have to implement a queueing model. The model has 2 servers and 1 queue. Let’s say we
# have server-1 and server-2.
# The arrival of the customer: If both servers are idle, the customer will go to server-1. If any of the
# servers are idle and the other one is busy then the customer will go to Idle sever. If both servers
# are busy then the customer will stand in the queue.
# The departure of a customer: Departure can occur from any of the servers. Then the next
# customer from the queue will be chosen according to queue policy (FIFO, LIFO, or SJF). [See
# the class lecture for solution hint]

# %% [markdown]
# Tasks:
# 1. Print clock_value, server_status of both servers, arrival list of queue, service times in
# queue, next_arrival time, next_departure time of both servers, total delay,
# area_under_q(t), area_under_b(t) for both servers at each clock step.
# 2. We have to implement SJF, LIFO. Report average_delay, expected number of customers
# in the queue, expected utilization of the server-1, and server-2 for each queue policy.
# 3. Important: You cannot make separate files for each queue policy. You have to
# submit just one .py file. You can input a variable in your code to choose the queue
# policy. For example 1 for FIFO, 2 for SJF, and 3 for LIFO.
# 4. You can use the given Inter-arrivals and service times in your code.
# Inter-arrival Times: A 1 = 0.4, A 2 = 1.2, A 3 = 0.5, A 4 =1.7, A 5 = 0.2, A 6 = 1.6, A 7 = 0.2, A 8 = 1.4, A 9 = 1.9, A10 = 0.7
# Service times are: S 1 = 2.0, S 2 = 0.7, S3 = 0.2, S4 = 1.1, S5 = 3.7, S6 = 0.6
# 5. Then take interarrival and service times randomly from exponential distribution of mean
# = 1.2 for inter-arrival times and mean = 1.3 for service times. You can use the
# np.random.exponential(mean, size) function from python to do this job. ( use
# np.random.seed(0) for consistent values
# 6. Prepare a report like below:
# Take Interarrival times = exponential with mean 1.2
# Take Service times = exponential with mean 1.3
# Run the Simulation for 3 cases: num_delays until 10, 30, and 60 customers.

# %% [markdown]
# ## Run code

# %%
import numpy as np
import math

# %%
class DSSQ:

    def __init__(self, n):
        np.random.seed(0) # seed 0
        self.interarrivals = list(np.random.exponential(1.2, n)) # exponential with mean 1.2
        self.service_times = list(np.random.exponential(1.3, n)) # exponential with mean 1.3
        # testing samples
        # self.interarrivals = [0.4, 1.2, 0.5, 1.7, 0.2, 1.6, 0.2, 1.4, 1.9, 0.7]
        # self.service_times = [2.0, 0.7, 0.2, 1.1, 3.7, 0.6, 1.2, 2.1, 0.5]

        self.clock = 0.0
        #for server 1
        self.next_arrival_time = self.interarrivals.pop(0) 
        self.next_departure_time = math.inf
        self.server_status = 0 #IDLE server 1

        # for server 2
        self.next_departure_time_2 = math.inf
        self.server_status_2 = 0 #IDLE server 2

        self.num_in_queue = 0

        self.times_of_arrival_in_queue=[] #Store arrival times of the customers in the queue
        self.service_times_in_queue=[]  #Store service times of the customers in the queue
         
        self.num_of_delay = 0 
        self.total_delay = 0

        # qt and bt part
        self.area_under_qt = 0.0
        self.area_under_bt = 0.0 # for server 1
        self.area_under_bt_2 = 0.0 # for server 2

        self.last_event_time = 0 #for calculate time diffrence
        self.last_server_status = 0 # for last server status1
        self.last_server_status_2 = 0 # for last server status2
        self.last_num_in_queue = 0 # for last number in queue

        #for the initial one. clock 0

        print("Clock: ", self.clock)
        print("Server 1 Status: ", self.server_status)
        print("Server 2 Status: ", self.server_status_2)

        print("Number of Queue: ", self.num_in_queue)
        print("Times of arrivals in Queue: ", self.times_of_arrival_in_queue)
        print("Service times in Queue: ", self.service_times_in_queue)

        print("Next Arrival Time: ", self.next_arrival_time)
        print("Next Departure Time of server 1: ", self.next_departure_time)
        print("Next Departure Time of server 2: ", self.next_departure_time_2)

        print("Number of Delays: ", self.num_of_delay)
        print("Total Delay: ", self.total_delay)

        print("Area under Q(t): ", self.area_under_qt)
        print("Area under B(t): ", self.area_under_bt)
        print("Area under B(t)2: ", self.area_under_bt_2)

        
        print("\n---------------------------------------------------------------\n")
    
    def start_simulation(self, n, queue_type):  #Start the simulation
        while self.num_of_delay<n: # simulate untill n cuntomer delay
            self.timing(queue_type)
        # performance meuser of server.
        average_delay = round((self.total_delay / n) , 4)
        expected_number_in_queue = round((self.area_under_qt / self.clock) , 4)
        expected_utilization_of_server_1 = round((self.area_under_bt / self.clock) , 4)
        expected_utilization_of_server_2 = round((self.area_under_bt_2 / self.clock) , 4)

        print("Performance Measure")
        print("Aerrage Delay: ", average_delay)
        print("Expected Number of Customers in the queue: ", expected_number_in_queue)
        print("Expected Utilization of the server-1: ", expected_utilization_of_server_1)
        print("Expected Utilization of the server-2: ", expected_utilization_of_server_2)
        print("\n----------------------------x-x-x-x-x-x-x----------------------------\n")

    
    def timing(self, queue_type): #Clock moves forward according to next event time (A/D)
        self.clock= min(self.next_arrival_time, self.next_departure_time, self.next_departure_time_2)

        if self.clock == self.next_arrival_time:
            self.arrival()
            print("Clock: ", self.clock, " (A)")
        elif self.clock == self.next_departure_time:
            self.departure(queue_type)
            print("Clock: ", self.clock, " (D1)")
        elif self.clock == self.next_departure_time_2:
            self.departure_2(queue_type)
            print("Clock: ", self.clock, " (D2)")
        
        self.update_register() #this will update qt and bt

        print("Server 1 Status: ", self.server_status)
        print("Server 2 Status: ", self.server_status_2)

        print("Number of Queue: ", self.num_in_queue)
        print("Times of arrivals in Queue: ", self.times_of_arrival_in_queue)
        print("Service times in Queue: ", self.service_times_in_queue)

        print("Next Arrival Time: ", self.next_arrival_time)
        print("Next Departure Time of server 1: ", self.next_departure_time)
        print("Next Departure Time of server 2: ", self.next_departure_time_2)

        print("Number of Delays: ", self.num_of_delay)
        print("Total Delay: ", self.total_delay)

        print("Area under Q(t): ", self.area_under_qt)
        print("Area under B(t): ", self.area_under_bt)
        print("Area under B(t)2: ", self.area_under_bt_2)
        
        print("\n---------------------------------------------------------------\n")


    def arrival(self): #Arrival algortihm
        self.next_arrival_time += self.interarrivals.pop(0)

        if self.server_status is 0: #server 1 is idle
            self.num_of_delay += 1
            self.server_status = 1
            self.next_departure_time = self.clock + self.service_times.pop(0)

        elif self.server_status_2 is 0: #server 2 is idle
            self.num_of_delay += 1
            self.server_status_2 = 1
            self.next_departure_time_2 = self.clock + self.service_times.pop(0)

        else : #server 1 and 2 is busy
            self.num_in_queue += 1
            self.times_of_arrival_in_queue.append(self.clock)#Store Arrival times of the cutomer in the queue
            self.service_times_in_queue.append(self.service_times.pop(0)) #Store service time of the customer in the queue


    def departure(self, queue_type): #Departure Algorithm
        if self.num_in_queue == 0: # queue is empty
            self.server_status = 0
            self.next_departure_time = math.inf
        
        else: # queue is not empty
            self.num_in_queue -= 1
            self.num_of_delay += 1

            #AS FIFO, pop first arrival and service time from the queue. 
            #IF LIFO we have to pop last arrival and service time
            #For SJF, finf the index of minimum service time from  service_times_in_queue list.
            #Then pop the arrival of that index from times_of_arrivalqueue for delay count and others.  
            
            if queue_type is "FIFO" :
                arrival = self.times_of_arrival_in_queue.pop(0) 
                self.next_departure_time = self.clock + self.service_times_in_queue.pop(0)
            
            elif queue_type is "LIFO" :
                arrival = self.times_of_arrival_in_queue.pop(-1) 
                self.next_departure_time = self.clock + self.service_times_in_queue.pop(-1)
            
            elif queue_type is "SJF" :
                min_index = self.service_times_in_queue.index(min(self.service_times_in_queue))
                arrival = self.times_of_arrival_in_queue.pop(min_index) 
                self.next_departure_time = self.clock + self.service_times_in_queue.pop(min_index)

            delay = self.clock - arrival
            self.total_delay += delay

    def departure_2(self, queue_type): #Departure Algorithm
        if self.num_in_queue == 0: # queue is empty
            self.server_status_2 = 0
            self.next_departure_time_2 = math.inf
        
        else: # queue is not empty
            self.num_in_queue -= 1
            self.num_of_delay += 1

            #AS FIFO, pop first arrival and service time from the queue. 
            #IF LIFO we have to pop last arrival and service time
            #For SJF, finf the index of minimum service time from  service_times_in_queue list.
            #Then pop the arrival of that index from times_of_arrivalqueue for delay count and others.  
            
            if queue_type is "FIFO" :
                arrival = self.times_of_arrival_in_queue.pop(0) 
                self.next_departure_time_2 = self.clock + self.service_times_in_queue.pop(0)
            
            elif queue_type is "LIFO" :
                arrival = self.times_of_arrival_in_queue.pop(-1) 
                self.next_departure_time_2 = self.clock + self.service_times_in_queue.pop(-1)
            
            elif queue_type is "SJF" :
                min_index = self.service_times_in_queue.index(min(self.service_times_in_queue))
                arrival = self.times_of_arrival_in_queue.pop(min_index) 
                self.next_departure_time_2 = self.clock + self.service_times_in_queue.pop(min_index)

            delay = self.clock - arrival
            self.total_delay += delay

    def update_register(self): #for qt and bt calculation.
        time_difference = self.clock - self.last_event_time
        self.area_under_qt +=  time_difference* self.last_num_in_queue
        self.area_under_bt +=  time_difference* self.last_server_status
        self.area_under_bt_2 +=  time_difference* self.last_server_status_2

        #update next event
        self.last_event_time = self.clock
        self.last_num_in_queue = self.num_in_queue
        self.last_server_status = self.server_status
        self.last_server_status_2 = self.server_status_2

# %%
number_of_cases = [10, 30, 60]

for n in number_of_cases:
    print("N : ", n)

    print("\n------------------------FIFO-------------------------------\n")
    server = DSSQ(100)
    server.start_simulation(n, "FIFO")

    print("\n------------------------LIFO-------------------------------\n")
    server.__init__(100)
    server.start_simulation(n, "LIFO")

    print("\n------------------------SJF-------------------------------\n")
    server.__init__(100)
    server.start_simulation(n, "SJF")
    print("\n\n\n\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Clock:  50.897680068048444  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  54.35117816253767
# Next Departure Time of server 1:  52.27439228563277
# Next Departure Time of server 2:  inf
# Number of Delays:  38
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  30.149195154751606
# Area under B(t)2:  20.305816671644216
#
# ---------------------------------------------------------------
#
# Clock:  52.27439228563277  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  54.35117816253767
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  38
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  31.525907372335933
# Area under B(t)2:  20.305816671644216
#
# ---------------------------------------------------------------
#
# Clock:  54.35117816253767  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  55.725344912918125
# Next Departure Time of server 1:  55.72378263750138
# Next Departure Time of server 2:  inf
# Number of Delays:  39
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  31.525907372335933
# Area under B(t)2:  20.305816671644216
#
# ---------------------------------------------------------------
#
# Clock:  55.72378263750138  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  55.725344912918125
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  39
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  32.898511847299645
# Area under B(t)2:  20.305816671644216
#
# ---------------------------------------------------------------
#
# Clock:  55.725344912918125  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  56.25996710419561
# Next Departure Time of server 1:  56.45933856654732
# Next Departure Time of server 2:  inf
# Number of Delays:  40
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  32.898511847299645
# Area under B(t)2:  20.305816671644216
#
# ---------------------------------------------------------------
#
# Clock:  56.25996710419561  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  56.94940599470459
# Next Departure Time of server 1:  56.45933856654732
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  41
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  33.43313403857713
# Area under B(t)2:  20.305816671644216
#
# ---------------------------------------------------------------
#
# Clock:  56.45933856654732  (D1)
# Server 1 Status:  0
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  56.94940599470459
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  41
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  33.63250550092884
# Area under B(t)2:  20.50518813399593
#
# ---------------------------------------------------------------
#
# Clock:  56.94940599470459  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  58.38473535606464
# Next Departure Time of server 1:  57.54503074055387
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  42
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  33.63250550092884
# Area under B(t)2:  20.995255562153197
#
# ---------------------------------------------------------------
#
# Clock:  57.54503074055387  (D1)
# Server 1 Status:  0
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  58.38473535606464
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  42
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  34.22813024677812
# Area under B(t)2:  21.590880308002475
#
# ---------------------------------------------------------------
#
# Clock:  58.38473535606464  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  58.459273711175015
# Next Departure Time of server 1:  59.128935386597504
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  43
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  34.22813024677812
# Area under B(t)2:  22.430584923513244
#
# ---------------------------------------------------------------
#
# Clock:  58.459273711175015  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [58.459273711175015]
# Service times in Queue:  [2.892389016111249]
# Next Arrival Time:  59.777968687244666
# Next Departure Time of server 1:  59.128935386597504
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  43
# Total Delay:  4.507506324836843
# Area under Q(t):  4.507506324836843
# Area under B(t):  34.3026686018885
# Area under B(t)2:  22.50512327862362
#
# ---------------------------------------------------------------
#
# Clock:  59.128935386597504  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  59.777968687244666
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  59.209191264035184
# Number of Delays:  44
# Total Delay:  5.177168000259332
# Area under Q(t):  5.177168000259332
# Area under B(t):  34.97233027731099
# Area under B(t)2:  23.17478495404611
#
# ---------------------------------------------------------------
#
# Clock:  59.209191264035184  (D2)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  59.777968687244666
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  inf
# Number of Delays:  44
# Total Delay:  5.177168000259332
# Area under Q(t):  5.177168000259332
# Area under B(t):  35.05258615474867
# Area under B(t)2:  23.25504083148379
#
# ---------------------------------------------------------------
#
# Clock:  59.777968687244666  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  61.11068560719792
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  61.911135520096785
# Number of Delays:  45
# Total Delay:  5.177168000259332
# Area under Q(t):  5.177168000259332
# Area under B(t):  35.62136357795815
# Area under B(t)2:  23.25504083148379
#
# ---------------------------------------------------------------
#
# Clock:  61.11068560719792  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [61.11068560719792]
# Service times in Queue:  [1.582125335080137]
# Next Arrival Time:  61.39413365359873
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  61.911135520096785
# Number of Delays:  45
# Total Delay:  5.177168000259332
# Area under Q(t):  5.177168000259332
# Area under B(t):  36.954080497911406
# Area under B(t)2:  24.587757751437046
#
# ---------------------------------------------------------------
#
# Clock:  61.39413365359873  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [61.11068560719792, 61.39413365359873]
# Service times in Queue:  [1.582125335080137, 0.13729643778927425]
# Next Arrival Time:  61.55976807875767
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  61.911135520096785
# Number of Delays:  45
# Total Delay:  5.177168000259332
# Area under Q(t):  5.460616046660139
# Area under B(t):  37.23752854431221
# Area under B(t)2:  24.871205797837852
#
# ---------------------------------------------------------------
#
# Clock:  61.55976807875767  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [61.11068560719792, 61.39413365359873, 61.55976807875767]
# Service times in Queue:  [1.582125335080137, 0.13729643778927425, 3.2750667814157075]
# Next Arrival Time:  62.01452243812144
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  61.911135520096785
# Number of Delays:  45
# Total Delay:  5.177168000259332
# Area under Q(t):  5.791884896978022
# Area under B(t):  37.403162969471154
# Area under B(t)2:  25.036840222996794
#
# ---------------------------------------------------------------
#
# Clock:  61.911135520096785  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [61.39413365359873, 61.55976807875767]
# Service times in Queue:  [0.13729643778927425, 3.2750667814157075]
# Next Arrival Time:  62.01452243812144
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  63.49326085517692
# Number of Delays:  46
# Total Delay:  5.977617913158195
# Area under Q(t):  6.845987220995365
# Area under B(t):  37.75453041081027
# Area under B(t)2:  25.38820766433591
#
# ---------------------------------------------------------------
#
# Clock:  62.01452243812144  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [61.39413365359873, 61.55976807875767, 62.01452243812144]
# Service times in Queue:  [0.13729643778927425, 3.2750667814157075, 1.6283897876981832]
# Next Arrival Time:  62.5570449057371
# Next Departure Time of server 1:  62.02132440270876
# Next Departure Time of server 2:  63.49326085517692
# Number of Delays:  46
# Total Delay:  5.977617913158195
# Area under Q(t):  7.052761057044673
# Area under B(t):  37.85791732883492
# Area under B(t)2:  25.491594582360563
#
# ---------------------------------------------------------------
#
# Clock:  62.02132440270876  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [61.55976807875767, 62.01452243812144]
# Service times in Queue:  [3.2750667814157075, 1.6283897876981832]
# Next Arrival Time:  62.5570449057371
# Next Departure Time of server 1:  62.15862084049803
# Next Departure Time of server 2:  63.49326085517692
# Number of Delays:  47
# Total Delay:  6.604808662268223
# Area under Q(t):  7.073166950806627
# Area under B(t):  37.86471929342224
# Area under B(t)2:  25.49839654694788
#
# ---------------------------------------------------------------
#
# Clock:  62.15862084049803  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [62.01452243812144]
# Service times in Queue:  [1.6283897876981832]
# Next Arrival Time:  62.5570449057371
# Next Departure Time of server 1:  65.43368762191373
# Next Departure Time of server 2:  63.49326085517692
# Number of Delays:  48
# Total Delay:  7.203661424008583
# Area under Q(t):  7.347759826385175
# Area under B(t):  38.002015731211515
# Area under B(t)2:  25.635692984737155
#
# ---------------------------------------------------------------
#
# Clock:  62.5570449057371  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [62.01452243812144, 62.5570449057371]
# Service times in Queue:  [1.6283897876981832, 8.795011854251642]
# Next Arrival Time:  63.570358242518196
# Next Departure Time of server 1:  65.43368762191373
# Next Departure Time of server 2:  63.49326085517692
# Number of Delays:  48
# Total Delay:  7.203661424008583
# Area under Q(t):  7.746183891624245
# Area under B(t):  38.400439796450584
# Area under B(t)2:  26.034117049976224
#
# ---------------------------------------------------------------
#
# Clock:  63.49326085517692  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [62.5570449057371]
# Service times in Queue:  [8.795011854251642]
# Next Arrival Time:  63.570358242518196
# Next Departure Time of server 1:  65.43368762191373
# Next Departure Time of server 2:  65.12165064287511
# Number of Delays:  49
# Total Delay:  8.682399841064065
# Area under Q(t):  9.618615790503885
# Area under B(t):  39.336655745890404
# Area under B(t)2:  26.970332999416044
#
# ---------------------------------------------------------------
#
# Clock:  63.570358242518196  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [62.5570449057371, 63.570358242518196]
# Service times in Queue:  [8.795011854251642, 0.21043111270774006]
# Next Arrival Time:  64.26314741563371
# Next Departure Time of server 1:  65.43368762191373
# Next Departure Time of server 2:  65.12165064287511
# Number of Delays:  49
# Total Delay:  8.682399841064065
# Area under Q(t):  9.69571317784516
# Area under B(t):  39.41375313323168
# Area under B(t)2:  27.04743038675732
#
# ---------------------------------------------------------------
#
# Clock:  64.26314741563371  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [62.5570449057371, 63.570358242518196, 64.26314741563371]
# Service times in Queue:  [8.795011854251642, 0.21043111270774006, 2.6336814305645646]
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  65.43368762191373
# Next Departure Time of server 2:  65.12165064287511
# Number of Delays:  49
# Total Delay:  8.682399841064065
# Area under Q(t):  11.081291524076189
# Area under B(t):  40.106542306347194
# Area under B(t)2:  27.740219559872834
#
# ---------------------------------------------------------------
#
# Clock:  65.12165064287511  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [63.570358242518196, 64.26314741563371]
# Service times in Queue:  [0.21043111270774006, 2.6336814305645646]
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  65.43368762191373
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  50
# Total Delay:  11.247005578202074
# Area under Q(t):  13.656801205800388
# Area under B(t):  40.965045533588594
# Area under B(t)2:  28.598722787114234
#
# ---------------------------------------------------------------
#
# Clock:  65.43368762191373  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [64.26314741563371]
# Service times in Queue:  [2.6336814305645646]
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  65.64411873462147
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  51
# Total Delay:  13.110334957597612
# Area under Q(t):  14.280875163877635
# Area under B(t):  41.27708251262722
# Area under B(t)2:  28.910759766152857
#
# ---------------------------------------------------------------
#
# Clock:  65.64411873462147  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  68.27780016518604
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  52
# Total Delay:  14.491306276585373
# Area under Q(t):  14.491306276585373
# Area under B(t):  41.487513625334955
# Area under B(t)2:  29.121190878860595
#
# ---------------------------------------------------------------
#
# Clock:  68.27780016518604  (D1)
# Server 1 Status:  0
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  52
# Total Delay:  14.491306276585373
# Area under Q(t):  14.491306276585373
# Area under B(t):  44.12119505589952
# Area under B(t)2:  31.75487230942516
#
# ---------------------------------------------------------------
#
# Clock:  69.60854427236457  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  69.73770640740692
# Next Departure Time of server 1:  69.83906752520912
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  53
# Total Delay:  14.491306276585373
# Area under Q(t):  14.491306276585373
# Area under B(t):  44.12119505589952
# Area under B(t)2:  33.08561641660369
#
# ---------------------------------------------------------------
#
# Clock:  69.73770640740692  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [69.73770640740692]
# Service times in Queue:  [1.2427563403435309]
# Next Arrival Time:  70.01886822616646
# Next Departure Time of server 1:  69.83906752520912
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  53
# Total Delay:  14.491306276585373
# Area under Q(t):  14.491306276585373
# Area under B(t):  44.25035719094187
# Area under B(t)2:  33.21477855164604
#
# ---------------------------------------------------------------
#
# Clock:  69.83906752520912  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  70.01886822616646
# Next Departure Time of server 1:  71.08182386555265
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  54
# Total Delay:  14.592667394387572
# Area under Q(t):  14.592667394387572
# Area under B(t):  44.35171830874407
# Area under B(t)2:  33.31613966944824
#
# ---------------------------------------------------------------
#
# Clock:  70.01886822616646  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [70.01886822616646]
# Service times in Queue:  [0.1718388231656995]
# Next Arrival Time:  70.22996449028798
# Next Departure Time of server 1:  71.08182386555265
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  54
# Total Delay:  14.592667394387572
# Area under Q(t):  14.592667394387572
# Area under B(t):  44.53151900970141
# Area under B(t)2:  33.495940370405584
#
# ---------------------------------------------------------------
#
# Clock:  70.22996449028798  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [70.01886822616646, 70.22996449028798]
# Service times in Queue:  [0.1718388231656995, 2.4491075698431635]
# Next Arrival Time:  71.50045576017568
# Next Departure Time of server 1:  71.08182386555265
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  54
# Total Delay:  14.592667394387572
# Area under Q(t):  14.803763658509094
# Area under B(t):  44.742615273822935
# Area under B(t)2:  33.70703663452711
#
# ---------------------------------------------------------------
#
# Clock:  71.08182386555265  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [70.22996449028798]
# Service times in Queue:  [2.4491075698431635]
# Next Arrival Time:  71.50045576017568
# Next Departure Time of server 1:  71.25366268871835
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  55
# Total Delay:  15.655623033773761
# Area under Q(t):  16.507482409038428
# Area under B(t):  45.5944746490876
# Area under B(t)2:  34.55889600979177
#
# ---------------------------------------------------------------
#
# Clock:  71.25366268871835  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  71.50045576017568
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  16.679321232204128
# Area under B(t):  45.7663134722533
# Area under B(t)2:  34.730734832957474
#
# ---------------------------------------------------------------
#
# Clock:  71.50045576017568  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [71.50045576017568]
# Service times in Queue:  [2.1407348209874164]
# Next Arrival Time:  71.85095240206441
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  16.679321232204128
# Area under B(t):  46.013106543710634
# Area under B(t)2:  34.977527904414806
#
# ---------------------------------------------------------------
#
# Clock:  71.85095240206441  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187]
# Next Arrival Time:  72.60448229935344
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  17.029817874092853
# Area under B(t):  46.36360318559936
# Area under B(t)2:  35.32802454630353
#
# ---------------------------------------------------------------
#
# Clock:  72.60448229935344  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.60448229935344]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.6797310381260057]
# Next Arrival Time:  72.94081471579688
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  18.536877668670908
# Area under B(t):  47.11713308288839
# Area under B(t)2:  36.08155444359256
#
# ---------------------------------------------------------------
#
# Clock:  72.94081471579688  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  4
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.60448229935344, 72.94081471579688]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.6797310381260057, 0.09317800690437092]
# Next Arrival Time:  73.14856765912472
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  19.54587491800123
# Area under B(t):  47.45346549933183
# Area under B(t)2:  36.417886860036
#
# ---------------------------------------------------------------
#
# Clock:  73.14856765912472  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  5
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.60448229935344, 72.94081471579688, 73.14856765912472]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.6797310381260057, 0.09317800690437092, 1.554070139113216]
# Next Arrival Time:  73.28891415357411
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  20.376886691312617
# Area under B(t):  47.661218442659674
# Area under B(t)2:  36.625639803363846
#
# ---------------------------------------------------------------
#
# Clock:  73.28891415357411  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  6
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.60448229935344, 72.94081471579688, 73.14856765912472, 73.28891415357411]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.6797310381260057, 0.09317800690437092, 1.554070139113216, 0.7855887991858944]
# Next Arrival Time:  74.57060078133308
# Next Departure Time of server 1:  73.70277025856151
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  56
# Total Delay:  16.679321232204128
# Area under Q(t):  21.078619163559562
# Area under B(t):  47.80156493710906
# Area under B(t)2:  36.765986297813235
#
# ---------------------------------------------------------------
#
# Clock:  73.70277025856151  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  5
# Times of arrivals in Queue:  [71.85095240206441, 72.60448229935344, 72.94081471579688, 73.14856765912472, 73.28891415357411]
# Service times in Queue:  [1.0944452330272187, 0.6797310381260057, 0.09317800690437092, 1.554070139113216, 0.7855887991858944]
# Next Arrival Time:  74.57060078133308
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  73.91666249712675
# Number of Delays:  57
# Total Delay:  18.88163573058996
# Area under Q(t):  23.56175579348398
# Area under B(t):  48.215421042096466
# Area under B(t)2:  37.17984240280064
#
# ---------------------------------------------------------------
#
# Clock:  73.91666249712675  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  4
# Times of arrivals in Queue:  [72.60448229935344, 72.94081471579688, 73.14856765912472, 73.28891415357411]
# Service times in Queue:  [0.6797310381260057, 0.09317800690437092, 1.554070139113216, 0.7855887991858944]
# Next Arrival Time:  74.57060078133308
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.01110773015397
# Number of Delays:  58
# Total Delay:  20.947345825652302
# Area under Q(t):  24.63121698631016
# Area under B(t):  48.4293132806617
# Area under B(t)2:  37.393734641365874
#
# ---------------------------------------------------------------
#
# Clock:  74.57060078133308  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  5
# Times of arrivals in Queue:  [72.60448229935344, 72.94081471579688, 73.14856765912472, 73.28891415357411, 74.57060078133308]
# Service times in Queue:  [0.6797310381260057, 0.09317800690437092, 1.554070139113216, 0.7855887991858944, 1.6644344384051315]
# Next Arrival Time:  74.74905550699903
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.01110773015397
# Number of Delays:  58
# Total Delay:  20.947345825652302
# Area under Q(t):  27.246970123135494
# Area under B(t):  49.083251564868036
# Area under B(t)2:  38.04767292557221
#
# ---------------------------------------------------------------
#
# Clock:  74.74905550699903  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  6
# Times of arrivals in Queue:  [72.60448229935344, 72.94081471579688, 73.14856765912472, 73.28891415357411, 74.57060078133308, 74.74905550699903]
# Service times in Queue:  [0.6797310381260057, 0.09317800690437092, 1.554070139113216, 0.7855887991858944, 1.6644344384051315, 2.6166045563786624]
# Next Arrival Time:  75.01171223024508
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.01110773015397
# Number of Delays:  58
# Total Delay:  20.947345825652302
# Area under Q(t):  28.139243751465212
# Area under B(t):  49.26170629053398
# Area under B(t)2:  38.22612765123815
#
# ---------------------------------------------------------------
#
# Clock:  75.01110773015397  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  5
# Times of arrivals in Queue:  [72.94081471579688, 73.14856765912472, 73.28891415357411, 74.57060078133308, 74.74905550699903]
# Service times in Queue:  [0.09317800690437092, 1.554070139113216, 0.7855887991858944, 1.6644344384051315, 2.6166045563786624]
# Next Arrival Time:  75.01171223024508
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.69083876827997
# Number of Delays:  59
# Total Delay:  23.353971256452834
# Area under Q(t):  29.711557090394844
# Area under B(t):  49.52375851368892
# Area under B(t)2:  38.48817987439309
#
# ---------------------------------------------------------------
#
# Clock:  75.01171223024508  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  6
# Times of arrivals in Queue:  [72.94081471579688, 73.14856765912472, 73.28891415357411, 74.57060078133308, 74.74905550699903, 75.01171223024508]
# Service times in Queue:  [0.09317800690437092, 1.554070139113216, 0.7855887991858944, 1.6644344384051315, 2.6166045563786624, 4.82294839273516]
# Next Arrival Time:  75.56372898891675
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.69083876827997
# Number of Delays:  59
# Total Delay:  23.353971256452834
# Area under Q(t):  29.714579590850416
# Area under B(t):  49.52436301378003
# Area under B(t)2:  38.488784374484204
#
# ---------------------------------------------------------------
#
# Clock:  75.56372898891675  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  7
# Times of arrivals in Queue:  [72.94081471579688, 73.14856765912472, 73.28891415357411, 74.57060078133308, 74.74905550699903, 75.01171223024508, 75.56372898891675]
# Service times in Queue:  [0.09317800690437092, 1.554070139113216, 0.7855887991858944, 1.6644344384051315, 2.6166045563786624, 4.82294839273516, 2.5175504032469056]
# Next Arrival Time:  77.6281269710504
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.69083876827997
# Number of Delays:  59
# Total Delay:  23.353971256452834
# Area under Q(t):  33.02668014288044
# Area under B(t):  50.0763797724517
# Area under B(t)2:  39.040801133155874
#
# ---------------------------------------------------------------
#
# Clock:  75.69083876827997  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  6
# Times of arrivals in Queue:  [73.14856765912472, 73.28891415357411, 74.57060078133308, 74.74905550699903, 75.01171223024508, 75.56372898891675]
# Service times in Queue:  [1.554070139113216, 0.7855887991858944, 1.6644344384051315, 2.6166045563786624, 4.82294839273516, 2.5175504032469056]
# Next Arrival Time:  77.6281269710504
# Next Departure Time of server 1:  75.84350507954893
# Next Departure Time of server 2:  75.78401677518434
# Number of Delays:  60
# Total Delay:  26.103995308935932
# Area under Q(t):  33.916448598423
# Area under B(t):  50.203489551814926
# Area under B(t)2:  39.1679109125191
#
# ---------------------------------------------------------------
#
# Performance Measure
# Aerrage Delay:  0.4351
# Expected Number of Customers in the queue:  0.4481
# Expected Utilization of the server-1:  0.6633
# Expected Utilization of the server-2:  0.5175
#
# ----------------------------x-x-x-x-x-x-x----------------------------
#
#
# ------------------------LIFO-------------------------------
#
# Clock:  0.0
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  0.9550494097957319
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  0
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  0.0
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  0.9550494097957319  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  2.4621663253547372
# Next Departure Time of server 1:  2.427473784239866
# Next Departure Time of server 2:  inf
# Number of Delays:  1
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  0.0
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  2.427473784239866  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  2.4621663253547372
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  1
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  1.472424374444134
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  2.4621663253547372  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  3.57003410031962
# Next Departure Time of server 1:  2.8713044925592515
# Next Departure Time of server 2:  inf
# Number of Delays:  2
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  1.472424374444134
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  2.8713044925592515  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  3.57003410031962
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  2
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  1.8815625416486483
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  3.57003410031962  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  4.514675483100345
# Next Departure Time of server 1:  5.297419344460497
# Next Departure Time of server 2:  inf
# Number of Delays:  3
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  1.8815625416486483
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  4.514675483100345  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  5.175933672414944
# Next Departure Time of server 1:  5.297419344460497
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  4
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  2.8262039244293735
# Area under B(t)2:  0.0
#
# ---------------------------------------------------------------
#
# Clock:  5.175933672414944  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [5.175933672414944]
# Service times in Queue:  [0.37182727078567424]
# Next Arrival Time:  6.421724826347275
# Next Departure Time of server 1:  5.297419344460497
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  4
# Total Delay:  0
# Area under Q(t):  0.0
# Area under B(t):  3.4874621137439723
# Area under B(t)2:  0.6612581893145988
#
# ---------------------------------------------------------------
#
# Clock:  5.297419344460497  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  6.421724826347275
# Next Departure Time of server 1:  5.669246615246172
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  5
# Total Delay:  0.12148567204555327
# Area under Q(t):  0.12148567204555327
# Area under B(t):  3.6089477857895256
# Area under B(t)2:  0.7827438613601521
#
# ---------------------------------------------------------------
#
# Clock:  5.669246615246172  (D1)
# Server 1 Status:  0
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  6.421724826347275
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  5
# Total Delay:  0.12148567204555327
# Area under Q(t):  0.12148567204555327
# Area under B(t):  3.9807750565752
# Area under B(t)2:  1.1545711321458265
#
# ---------------------------------------------------------------
#
# Clock:  6.421724826347275  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  7.112347865349643
# Next Departure Time of server 1:  7.537635680008145
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  6
# Total Delay:  0.12148567204555327
# Area under Q(t):  0.12148567204555327
# Area under B(t):  3.9807750565752
# Area under B(t)2:  1.9070493432469302
#
# ---------------------------------------------------------------
#
# Clock:  7.112347865349643  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [7.112347865349643]
# Service times in Queue:  [1.1655681473599142]
# Next Arrival Time:  9.78057716098883
# Next Departure Time of server 1:  7.537635680008145
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  6
# Total Delay:  0.12148567204555327
# Area under Q(t):  0.12148567204555327
# Area under B(t):  4.671398095577568
# Area under B(t)2:  2.597672382249298
#
# ---------------------------------------------------------------
#
# Clock:  7.537635680008145  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  9.78057716098883
# Next Departure Time of server 1:  8.703203827368059
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  7
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  5.0966859102360695
# Area under B(t)2:  3.0229601969077997
#
# ---------------------------------------------------------------
#
# Clock:  8.703203827368059  (D1)
# Server 1 Status:  0
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  9.78057716098883
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  8.772361621055587
# Number of Delays:  7
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  6.2622540575959835
# Area under B(t)2:  4.188528344267714
#
# ---------------------------------------------------------------
#
# Clock:  8.772361621055587  (D2)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  9.78057716098883
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  7
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  6.2622540575959835
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  9.78057716098883  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  13.758471779453407
# Next Departure Time of server 1:  10.884564229074835
# Next Departure Time of server 2:  inf
# Number of Delays:  8
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  6.2622540575959835
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  10.884564229074835  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  13.758471779453407
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  8
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  7.366241125681988
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  13.758471779453407  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  14.338794300536112
# Next Departure Time of server 1:  14.086617773534966
# Next Departure Time of server 2:  inf
# Number of Delays:  9
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  7.366241125681988
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  14.086617773534966  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  14.338794300536112
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  9
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  7.694387119763547
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  14.338794300536112  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  16.221469668499115
# Next Departure Time of server 1:  18.3067605170176
# Next Departure Time of server 2:  inf
# Number of Delays:  10
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  7.694387119763547
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  16.221469668499115  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  17.12467859994302
# Next Departure Time of server 1:  18.3067605170176
# Next Departure Time of server 2:  16.991880904391916
# Number of Delays:  11
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  9.57706248772655
# Area under B(t)2:  4.257686137955242
#
# ---------------------------------------------------------------
#
# Clock:  16.991880904391916  (D2)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  17.12467859994302
# Next Departure Time of server 1:  18.3067605170176
# Next Departure Time of server 2:  inf
# Number of Delays:  11
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  10.347473723619352
# Area under B(t)2:  5.028097373848044
#
# ---------------------------------------------------------------
#
# Clock:  17.12467859994302  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  18.13199801602961
# Next Departure Time of server 1:  18.3067605170176
# Next Departure Time of server 2:  19.560176497585104
# Number of Delays:  12
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  10.480271419170457
# Area under B(t)2:  5.028097373848044
#
# ---------------------------------------------------------------
#
# Clock:  18.13199801602961  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [18.13199801602961]
# Service times in Queue:  [1.5629101280722477]
# Next Arrival Time:  21.249903000740137
# Next Departure Time of server 1:  18.3067605170176
# Next Departure Time of server 2:  19.560176497585104
# Number of Delays:  12
# Total Delay:  0.5467734867040548
# Area under Q(t):  0.5467734867040548
# Area under B(t):  11.487590835257045
# Area under B(t)2:  6.035416789934632
#
# ---------------------------------------------------------------
#
# Clock:  18.3067605170176  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  21.249903000740137
# Next Departure Time of server 1:  19.869670645089847
# Next Departure Time of server 2:  19.560176497585104
# Number of Delays:  13
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.7215359876920466
# Area under B(t):  11.662353336245037
# Area under B(t)2:  6.210179290922624
#
# ---------------------------------------------------------------
#
# Clock:  19.560176497585104  (D2)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  21.249903000740137
# Next Departure Time of server 1:  19.869670645089847
# Next Departure Time of server 2:  inf
# Number of Delays:  13
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.7215359876920466
# Area under B(t):  12.91576931681254
# Area under B(t)2:  7.463595271490127
#
# ---------------------------------------------------------------
#
# Clock:  19.869670645089847  (D1)
# Server 1 Status:  0
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  21.249903000740137
# Next Departure Time of server 1:  inf
# Next Departure Time of server 2:  inf
# Number of Delays:  13
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.7215359876920466
# Area under B(t):  13.225263464317283
# Area under B(t)2:  7.463595271490127
#
# ---------------------------------------------------------------
#
# Clock:  21.249903000740137  (A)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  21.338325426635553
# Next Departure Time of server 1:  21.708829172507954
# Next Departure Time of server 2:  inf
# Number of Delays:  14
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.7215359876920466
# Area under B(t):  13.225263464317283
# Area under B(t)2:  7.463595271490127
#
# ---------------------------------------------------------------
#
# Clock:  21.338325426635553  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  21.447718661578353
# Next Departure Time of server 1:  21.708829172507954
# Next Departure Time of server 2:  23.523524292835027
# Number of Delays:  15
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.7215359876920466
# Area under B(t):  13.3136858902127
# Area under B(t)2:  7.463595271490127
#
# ---------------------------------------------------------------
#
# Clock:  21.447718661578353  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [21.447718661578353]
# Service times in Queue:  [0.6565243764014074]
# Next Arrival Time:  21.47222936559942
# Next Departure Time of server 1:  21.708829172507954
# Next Departure Time of server 2:  23.523524292835027
# Number of Delays:  15
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.7215359876920466
# Area under B(t):  13.4230791251555
# Area under B(t)2:  7.572988506432927
#
# ---------------------------------------------------------------
#
# Clock:  21.47222936559942  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [21.447718661578353, 21.47222936559942]
# Service times in Queue:  [0.6565243764014074, 2.7683491741400696]
# Next Arrival Time:  23.617214581137286
# Next Departure Time of server 1:  21.708829172507954
# Next Departure Time of server 2:  23.523524292835027
# Number of Delays:  15
# Total Delay:  0.7215359876920466
# Area under Q(t):  0.746046691713115
# Area under B(t):  13.447589829176568
# Area under B(t)2:  7.597499210453996
#
# ---------------------------------------------------------------
#
# Clock:  21.708829172507954  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [21.447718661578353]
# Service times in Queue:  [0.6565243764014074]
# Next Arrival Time:  23.617214581137286
# Next Departure Time of server 1:  24.477178346648024
# Next Departure Time of server 2:  23.523524292835027
# Number of Delays:  16
# Total Delay:  0.9581357946005795
# Area under Q(t):  1.2192463055301808
# Area under B(t):  13.684189636085101
# Area under B(t)2:  7.8340990173625284
#
# ---------------------------------------------------------------
#
# Clock:  23.523524292835027  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  23.617214581137286
# Next Departure Time of server 1:  24.477178346648024
# Next Departure Time of server 2:  24.180048669236434
# Number of Delays:  17
# Total Delay:  3.033941425857254
# Area under Q(t):  3.033941425857254
# Area under B(t):  15.498884756412174
# Area under B(t)2:  9.648794137689602
#
# ---------------------------------------------------------------
#
# Clock:  23.617214581137286  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [23.617214581137286]
# Service times in Queue:  [1.1316965641209995]
# Next Arrival Time:  25.424155659375543
# Next Departure Time of server 1:  24.477178346648024
# Next Departure Time of server 2:  24.180048669236434
# Number of Delays:  17
# Total Delay:  3.033941425857254
# Area under Q(t):  3.033941425857254
# Area under B(t):  15.592575044714433
# Area under B(t)2:  9.742484425991861
#
# ---------------------------------------------------------------
#
# Clock:  24.180048669236434  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  25.424155659375543
# Next Departure Time of server 1:  24.477178346648024
# Next Departure Time of server 2:  25.311745233357435
# Number of Delays:  18
# Total Delay:  3.596775513956402
# Area under Q(t):  3.596775513956402
# Area under B(t):  16.15540913281358
# Area under B(t)2:  10.30531851409101
#
# ---------------------------------------------------------------
#
# ...
# Clock:  62.02132440270876  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [61.55976807875767, 62.01452243812144]
# Service times in Queue:  [3.2750667814157075, 1.6283897876981832]
# Next Arrival Time:  62.5570449057371
# Next Departure Time of server 1:  63.60344973778889
# Next Departure Time of server 2:  62.04843195788606
# Number of Delays:  47
# Total Delay:  6.446187752587452
# Area under Q(t):  6.914546041125856
# Area under B(t):  37.889913006102276
# Area under B(t)2:  25.473202834267838
#
# ---------------------------------------------------------------
#
# Clock:  62.04843195788606  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [61.55976807875767]
# Service times in Queue:  [3.2750667814157075]
# Next Arrival Time:  62.5570449057371
# Next Departure Time of server 1:  63.60344973778889
# Next Departure Time of server 2:  63.67682174558424
# Number of Delays:  48
# Total Delay:  6.480097272352072
# Area under Q(t):  6.968761151480461
# Area under B(t):  37.91702056127958
# Area under B(t)2:  25.50031038944514
#
# ---------------------------------------------------------------
#
# Clock:  62.5570449057371  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [61.55976807875767, 62.5570449057371]
# Service times in Queue:  [3.2750667814157075, 8.795011854251642]
# Next Arrival Time:  63.570358242518196
# Next Departure Time of server 1:  63.60344973778889
# Next Departure Time of server 2:  63.67682174558424
# Number of Delays:  48
# Total Delay:  6.480097272352072
# Area under Q(t):  7.477374099331502
# Area under B(t):  38.42563350913062
# Area under B(t)2:  26.00892333729618
#
# ---------------------------------------------------------------
#
# Clock:  63.570358242518196  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [61.55976807875767, 62.5570449057371, 63.570358242518196]
# Service times in Queue:  [3.2750667814157075, 8.795011854251642, 0.21043111270774006]
# Next Arrival Time:  64.26314741563371
# Next Departure Time of server 1:  63.60344973778889
# Next Departure Time of server 2:  63.67682174558424
# Number of Delays:  48
# Total Delay:  6.480097272352072
# Area under Q(t):  9.504000772893693
# Area under B(t):  39.438946845911715
# Area under B(t)2:  27.022236674077277
#
# ---------------------------------------------------------------
#
# Clock:  63.60344973778889  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [61.55976807875767, 62.5570449057371]
# Service times in Queue:  [3.2750667814157075, 8.795011854251642]
# Next Arrival Time:  64.26314741563371
# Next Departure Time of server 1:  63.81388085049663
# Next Departure Time of server 2:  63.67682174558424
# Number of Delays:  49
# Total Delay:  6.513188767622768
# Area under Q(t):  9.603275258705782
# Area under B(t):  39.47203834118241
# Area under B(t)2:  27.055328169347973
#
# ---------------------------------------------------------------
#
# Clock:  63.67682174558424  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [62.5570449057371]
# Service times in Queue:  [8.795011854251642]
# Next Arrival Time:  64.26314741563371
# Next Departure Time of server 1:  63.81388085049663
# Next Departure Time of server 2:  66.95188852699995
# Number of Delays:  50
# Total Delay:  8.63024243444934
# Area under Q(t):  9.75001927429648
# Area under B(t):  39.54541034897776
# Area under B(t)2:  27.128700177143322
#
# ---------------------------------------------------------------
#
# Clock:  63.81388085049663  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  64.26314741563371
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  66.95188852699995
# Number of Delays:  51
# Total Delay:  9.88707837920887
# Area under Q(t):  9.88707837920887
# Area under B(t):  39.68246945389015
# Area under B(t)2:  27.26575928205571
#
# ---------------------------------------------------------------
#
# Clock:  64.26314741563371  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [64.26314741563371]
# Service times in Queue:  [2.6336814305645646]
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  66.95188852699995
# Number of Delays:  51
# Total Delay:  9.88707837920887
# Area under Q(t):  9.88707837920887
# Area under B(t):  40.13173601902723
# Area under B(t)2:  27.71502584719279
#
# ---------------------------------------------------------------
#
# Clock:  66.95188852699995  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  69.58556995756452
# Number of Delays:  52
# Total Delay:  12.57581949057511
# Area under Q(t):  12.57581949057511
# Area under B(t):  42.82047713039347
# Area under B(t)2:  30.403766958559032
#
# ---------------------------------------------------------------
#
# Clock:  69.58556995756452  (D2)
# Server 1 Status:  1
# Server 2 Status:  0
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  69.60854427236457
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  inf
# Number of Delays:  52
# Total Delay:  12.57581949057511
# Area under Q(t):  12.57581949057511
# Area under B(t):  45.454158560958035
# Area under B(t)2:  33.0374483891236
#
# ---------------------------------------------------------------
#
# Clock:  69.60854427236457  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  69.73770640740692
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  69.83906752520912
# Number of Delays:  53
# Total Delay:  12.57581949057511
# Area under Q(t):  12.57581949057511
# Area under B(t):  45.47713287575809
# Area under B(t)2:  33.0374483891236
#
# ---------------------------------------------------------------
#
# Clock:  69.73770640740692  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [69.73770640740692]
# Service times in Queue:  [1.2427563403435309]
# Next Arrival Time:  70.01886822616646
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  69.83906752520912
# Number of Delays:  53
# Total Delay:  12.57581949057511
# Area under Q(t):  12.57581949057511
# Area under B(t):  45.60629501080044
# Area under B(t)2:  33.16661052416595
#
# ---------------------------------------------------------------
#
# Clock:  69.83906752520912  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  70.01886822616646
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  71.08182386555265
# Number of Delays:  54
# Total Delay:  12.67718060837731
# Area under Q(t):  12.67718060837731
# Area under B(t):  45.707656128602636
# Area under B(t)2:  33.267971641968145
#
# ---------------------------------------------------------------
#
# Clock:  70.01886822616646  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [70.01886822616646]
# Service times in Queue:  [0.1718388231656995]
# Next Arrival Time:  70.22996449028798
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  71.08182386555265
# Number of Delays:  54
# Total Delay:  12.67718060837731
# Area under Q(t):  12.67718060837731
# Area under B(t):  45.88745682955998
# Area under B(t)2:  33.44777234292549
#
# ---------------------------------------------------------------
#
# Clock:  70.22996449028798  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [70.01886822616646, 70.22996449028798]
# Service times in Queue:  [0.1718388231656995, 2.4491075698431635]
# Next Arrival Time:  71.50045576017568
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  71.08182386555265
# Number of Delays:  54
# Total Delay:  12.67718060837731
# Area under Q(t):  12.888276872498832
# Area under B(t):  46.0985530936815
# Area under B(t)2:  33.65886860704701
#
# ---------------------------------------------------------------
#
# Clock:  71.08182386555265  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [70.22996449028798]
# Service times in Queue:  [2.4491075698431635]
# Next Arrival Time:  71.50045576017568
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  71.25366268871835
# Number of Delays:  55
# Total Delay:  13.740136247763498
# Area under Q(t):  14.591995623028165
# Area under B(t):  46.95041246894617
# Area under B(t)2:  34.51072798231168
#
# ---------------------------------------------------------------
#
# Clock:  71.25366268871835  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  0
# Times of arrivals in Queue:  []
# Service times in Queue:  []
# Next Arrival Time:  71.50045576017568
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  56
# Total Delay:  14.763834446193865
# Area under Q(t):  14.763834446193865
# Area under B(t):  47.12225129211187
# Area under B(t)2:  34.68256680547738
#
# ---------------------------------------------------------------
#
# Clock:  71.50045576017568  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  1
# Times of arrivals in Queue:  [71.50045576017568]
# Service times in Queue:  [2.1407348209874164]
# Next Arrival Time:  71.85095240206441
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  56
# Total Delay:  14.763834446193865
# Area under Q(t):  14.763834446193865
# Area under B(t):  47.3690443635692
# Area under B(t)2:  34.92935987693471
#
# ---------------------------------------------------------------
#
# Clock:  71.85095240206441  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187]
# Next Arrival Time:  72.60448229935344
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  56
# Total Delay:  14.763834446193865
# Area under Q(t):  15.11433108808259
# Area under B(t):  47.71954100545793
# Area under B(t)2:  35.279856518823436
#
# ---------------------------------------------------------------
#
# Clock:  72.60448229935344  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.60448229935344]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.6797310381260057]
# Next Arrival Time:  72.94081471579688
# Next Departure Time of server 1:  72.60889270474827
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  56
# Total Delay:  14.763834446193865
# Area under Q(t):  16.621390882660645
# Area under B(t):  48.473070902746954
# Area under B(t)2:  36.033386416112464
#
# ---------------------------------------------------------------
#
# Clock:  72.60889270474827  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187]
# Next Arrival Time:  72.94081471579688
# Next Departure Time of server 1:  73.28862374287428
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  57
# Total Delay:  14.768244851588701
# Area under Q(t):  16.634622098845153
# Area under B(t):  48.47748130814179
# Area under B(t)2:  36.0377968215073
#
# ---------------------------------------------------------------
#
# Clock:  72.94081471579688  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.94081471579688]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.09317800690437092]
# Next Arrival Time:  73.14856765912472
# Next Departure Time of server 1:  73.28862374287428
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  57
# Total Delay:  14.768244851588701
# Area under Q(t):  17.29846612094236
# Area under B(t):  48.809403319190395
# Area under B(t)2:  36.369718832555904
#
# ---------------------------------------------------------------
#
# Clock:  73.14856765912472  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  4
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 72.94081471579688, 73.14856765912472]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 0.09317800690437092, 1.554070139113216]
# Next Arrival Time:  73.28891415357411
# Next Departure Time of server 1:  73.28862374287428
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  57
# Total Delay:  14.768244851588701
# Area under Q(t):  17.921724950925903
# Area under B(t):  49.01715626251824
# Area under B(t)2:  36.57747177588375
#
# ---------------------------------------------------------------
#
# Clock:  73.28862374287428  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 73.14856765912472]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 1.554070139113216]
# Next Arrival Time:  73.28891415357411
# Next Departure Time of server 1:  73.38180174977865
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  58
# Total Delay:  15.116053878666104
# Area under Q(t):  18.481949285924127
# Area under B(t):  49.1572123462678
# Area under B(t)2:  36.71752785963331
#
# ---------------------------------------------------------------
#
# Clock:  73.28891415357411  (A)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  4
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 73.14856765912472, 73.28891415357411]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 1.554070139113216, 0.7855887991858944]
# Next Arrival Time:  74.57060078133308
# Next Departure Time of server 1:  73.38180174977865
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  58
# Total Delay:  15.116053878666104
# Area under Q(t):  18.482820518023626
# Area under B(t):  49.15750275696763
# Area under B(t)2:  36.71781827033314
#
# ---------------------------------------------------------------
#
# Clock:  73.38180174977865  (D1)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  3
# Times of arrivals in Queue:  [71.50045576017568, 71.85095240206441, 73.14856765912472]
# Service times in Queue:  [2.1407348209874164, 1.0944452330272187, 1.554070139113216]
# Next Arrival Time:  74.57060078133308
# Next Departure Time of server 1:  74.16739054896453
# Next Departure Time of server 2:  73.70277025856151
# Number of Delays:  59
# Total Delay:  15.208941474870638
# Area under Q(t):  18.85437090284176
# Area under B(t):  49.250390353172165
# Area under B(t)2:  36.810705866537674
#
# ---------------------------------------------------------------
#
# Clock:  73.70277025856151  (D2)
# Server 1 Status:  1
# Server 2 Status:  1
# Number of Queue:  2
# Times of arrivals in Queue:  [71.50045576017568, 73.14856765912472]
# Service times in Queue:  [2.1407348209874164, 1.554070139113216]
# Next Arrival Time:  74.57060078133308
# Next Departure Time of server 1:  74.16739054896453
# Next Departure Time of server 2:  74.79721549158873
# Number of Delays:  60
# Total Delay:  17.060759331367745
# Area under Q(t):  19.81727642919037
# Area under B(t):  49.571358861955034
# Area under B(t)2:  37.13167437532054
#
# ---------------------------------------------------------------
#
# Performance Measure
# Aerrage Delay:  0.2843
# Expected Number of Customers in the queue:  0.2689
# Expected Utilization of the server-1:  0.6726
# Expected Utilization of the server-2:  0.5038
#
# ----------------------------x-x-x-x-x-x-x----------------------------
